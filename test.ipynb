# %%
import streamlit as st
import pandas as pd


# set up training_dataset
df = pd.read_csv("training_dataset.csv")

# %%
df.describe()
# Out:
#        review_score         price  freight_value  product_photos_qty  \
# count  98344.000000  97619.000000   97619.000000        97619.000000
# mean       4.088607    137.568367      22.805388            2.218886
# std        1.345865    209.456318      21.634085            1.749359
# min        1.000000      0.850000       0.000000            0.000000
# 25%        4.000000     45.900000      13.840000            1.000000
# 50%        5.000000     86.900000      17.170000            1.500000
# 75%        5.000000    149.900000      24.010000            3.000000
# max        5.000000  13440.000000    1794.960000           20.000000
#
#        product_description_lenght         score  temps_livraison  \
# count                97619.000000  98344.000000     95542.000000
# mean                   782.734858      0.578236        12.050198
# std                    654.696926      0.493844         9.467396
# min                      0.000000      0.000000         0.000000
# 25%                    343.000000      0.000000         6.000000
# 50%                    600.000000      1.000000        10.000000
# 75%                    988.000000      1.000000        15.000000
# max                   3992.000000      1.000000       208.000000
#
#        retard_livraison  produit_recu
# count      95542.000000  98344.000000
# mean         -11.910228      0.920849
# std           10.109199      0.269975
# min         -147.000000      0.000000
# 25%          -17.000000      1.000000
# 50%          -12.000000      1.000000
# 75%           -7.000000      1.000000
# max          188.000000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98344 entries, 0 to 98343
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   review_id                      98344 non-null  object
#  1   order_id                       98344 non-null  object
#  2   review_score                   98344 non-null  int64
#  3   review_comment_title           11514 non-null  object
#  4   review_comment_message         40654 non-null  object
#  5   review_creation_date           98344 non-null  object
#  6   review_answer_timestamp        98344 non-null  object
#  7   customer_id                    98344 non-null  object
#  8   order_status                   98344 non-null  object
#  9   order_purchase_timestamp       98344 non-null  object
#  10  order_approved_at              98215 non-null  object
#  11  order_delivered_carrier_date   96634 non-null  object
#  12  order_delivered_customer_date  95542 non-null  object
#  13  order_estimated_delivery_date  98344 non-null  object
#  14  price                          97619 non-null  float64
#  15  freight_value                  97619 non-null  float64
#  16  product_photos_qty             97619 non-null  float64
#  17  product_description_lenght     97619 non-null  float64
#  18  score                          98344 non-null  int64
#  19  temps_livraison                95542 non-null  float64
#  20  retard_livraison               95542 non-null  float64
#  21  produit_recu                   98344 non-null  int64
# dtypes: float64(6), int64(3), object(13)
# memory usage: 16.5+ MB

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("training_dataset.csv")

st.set_page_config(page_title="Oliist Dataset")
st.header("Study of shipping revenues - Olist Dataset")
st.markdown("Explore the variables to understand their relationships and how they correlate with the species. "
            "As patterns emerge, we can intuitively understand how the RandomForestClassifier makes decisions in classifying data.")
st.sidebar.header("Variable Comparison")

colors = [(1/256,217/256,132/256), (249/256,185/256,0/256), (241/256,62/256,92/256),\
          (31/256,69/256,232/256)] #Vert, Jaune, Rouge, Bleu

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, squeeze=False, figsize=(20, 10))
 
sns.boxplot(data=df['freight_value'], showfliers=False, ax=ax1, color = colors[0])
sns.boxplot(data=df['freight_value'], showfliers=True, ax=ax2, color = colors[1])
sns.histplot(data=df['freight_value'], ax=ax3, color = colors[2])
# sum_price ="calculated price by: " +str(olist_orderitems_product.groupby("product_category_name")["price"].sum())
# print(sum_price)
frieght_value_total = 'frieght_value_total:' +str(df['freight_value'].sum())
# print(frieght_value_total)
ax4.text(0.2, 1.0, frieght_value_total, fontsize=20, ha='left', va='center')
# ax4.text(0.2, 0.8, somme_payment_outlier, fontsize=20, ha='left', va='center')
ax4.axis('off')
ax1.set_title('freight without std')
ax2.set_title('freight with std')
ax3.set_title('freight hist')
# Out:
# 2024-02-01 12:23:54.427
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 18
#      13 st.sidebar.header("Variable Comparison")
#      15 colors = [(1/256,217/256,132/256), (249/256,185/256,0/256), (241/256,62/256,92/256),\
#      16           (31/256,69/256,232/256)] #Vert, Jaune, Rouge, Bleu
# ---> 18 fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, squeeze=False, figsize=(20, 10))
#      20 sns.boxplot(data=df['freight_value'], showfliers=False, ax=ax1, color = colors[0])
#      21 sns.boxplot(data=df['freight_value'], showfliers=True, ax=ax2, color = colors[1])
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\_plotly_utils\importers.py:39, in relative_import.<locals>.__getattr__(import_name)
#      36     class_module = importlib.import_module(rel_module, parent_name)
#      37     return getattr(class_module, class_name)
# ---> 39 raise AttributeError(
#      40     "module {__name__!r} has no attribute {name!r}".format(
#      41         name=import_name, __name__=parent_name
#      42     )
#      43 )
#
# AttributeError: module 'plotly' has no attribute 'subplots'

# %%
df["produit_recu"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(5, 4))
ax = sns.countplot(x='score', data=df["freight_value"], palette='viridis')

# Add percentages to each bar
total = len(df['freight_value'])
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total)
    # percentage = 100 * p.get_height() / total
    print(type(percentage))
    x = p.get_x() + p.get_width() / 2 
    y = p.get_height() + 1000
    ax.annotate(percentage, (x, y), ha='center')


ax.set_title('Distribution des notes attribuées aux commandes')
ax.set_xlabel('Note obtenue')
ax.set_ylabel('Fréquence')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       4 import seaborn as sns
#       7 plt.figure(figsize=(5, 4))
# ----> 8 ax = sns.countplot(x='score', data=df["freight_value"], palette='viridis')
#      10 # Add percentages to each bar
#      11 total = len(df['freight_value'])
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\seaborn\categorical.py:2630, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2627 elif x is not None and y is not None:
#    2628     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2630 p = _CategoricalAggPlotter(
#    2631     data=data,
#    2632     variables=dict(x=x, y=y, hue=hue),
#    2633     order=order,
#    2634     orient=orient,
#    2635     color=color,
#    2636     legend=legend,
#    2637 )
#    2639 if ax is None:
#    2640     ax = plt.gca()
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\seaborn\categorical.py:66, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      55 def __init__(
#      56     self,
#      57     data=None,
#    (...)
#      63     legend="auto",
#      64 ):
# ---> 66     super().__init__(data=data, variables=variables)
#      68     # This method takes care of some bookkeeping that is necessary because the
#      69     # original categorical plots (prior to the 2021 refactor) had some rules that
#      70     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      75     # default VectorPlotter rules. If we do decide to make orient part of the
#      76     # _base variable assignment, we'll want to figure out how to express that.
#      77     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\seaborn\_core\data.py:57, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
# ---> 57     data = handle_data_source(data)
#      58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\seaborn\_core\data.py:278, in handle_data_source(data)
#     276 elif data is not None and not isinstance(data, Mapping):
#     277     err = f"Data source must be a DataFrame or Mapping, not {type(data)!r}."
# --> 278     raise TypeError(err)
#     280 return data
#
# TypeError: Data source must be a DataFrame or Mapping, not <class 'pandas.core.series.Series'>.

# %%
import plotly.express as px
plot1 = px.scatter(
    df,
    x="freight_value",
    y="score",
    title="Petal Length vs Petal Width",
    color="green")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 import plotly.express as px
# ----> 2 plot1 = px.scatter(
#       3     df,
#       4     x="freight_value",
#       5     y="score",
#       6     title="Petal Length vs Petal Width",
#       7     color="green")
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\plotly\express\_chart_types.py:66, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\plotly\express\_core.py:2076, in make_figure(args, constructor, trace_patch, layout_patch)
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\plotly\express\_core.py:1485, in build_dataframe(args, constructor)
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\Utilisateur\Desktop\Final_Week\Analyser_Oliist\env1\Lib\site-packages\plotly\express\_core.py:1210, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1210         raise ValueError(err_msg)
#    1211 elif length and len(df_input[argument]) != length:
#    1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1221         )
#    1222     )
#
# ValueError: Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['review_id', 'order_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'price', 'freight_value', 'product_photos_qty', 'product_description_lenght', 'score', 'temps_livraison', 'retard_livraison', 'produit_recu'] but received: green
